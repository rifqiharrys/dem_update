# %% [markdown]
# # DEM Update Using Generic Mapping Tools python bindings (pyGMT)

# %% [markdown]
# ## Preparation

# %% [markdown]
# ### Imports

# %%
from pathlib import Path

import geopandas as gpd
import numpy as np
import pandas as pd
import pygmt
import rioxarray as rxr
import xarray as xr

from dem_tools import dem2xyz, read_dem

# %% [markdown]
# ### Old and new data

# %%
old_path = Path(r'./data/BATNAS_120E-125E_05S-000_MSL_v1.5.tif')
new_path = Path(r'./data/DEM_INTEGRASI_TOGEAN_10m_FINAL.tif')
update_path = old_path.name.replace('v1.5', 'v2.0')

# %%
old_dem = read_dem(old_path, crs='EPSG:4326', chunks='auto')
old_dem
# Out:
# <xarray.DataArray (band: 1, y: 3000, x: 3000)> Size: 36MB
# dask.array<open_rasterio-11351d40e579691b94b1b4b4a38e067e<this-array>, shape=(1, 3000, 3000), dtype=float32, chunksize=(1, 3000, 3000), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) int64 8B 1
#   * y            (y) float64 24kB -0.0008333 -0.0025 -0.004167 ... -4.998 -4.999
#   * x            (x) float64 24kB 120.0 120.0 120.0 120.0 ... 125.0 125.0 125.0
#     spatial_ref  int64 8B 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0

# %%
left, bottom, right, top = old_dem.rio.bounds()

# %% [markdown]
# ### Preprocess

# %% [markdown]
# Check if the data have the right CRS and assign the right CRS if they don't.

# %%
pygmt.grd2xyz(
    grid=old_dem,
    output_type='file',
    outfile=old_path.with_suffix('.xyz'),
)
# Out:
# c:\Users\LENOVO\miniforge3\envs\py3_12\Lib\site-packages\pygmt\helpers\decorators.py:818: RuntimeWarning: Input image has dtype: float32 which is unsupported, and may result in an incorrect output. Please recast image to a uint8 dtype and/or scale to 0-255 range, e.g. using a histogram equalization function like skimage.exposure.equalize_hist.
#   return module_func(*args, **kwargs)

# %%
new_dem = read_dem(new_path, chunks='auto')
new_dem
# Out:
# <xarray.DataArray (band: 1, y: 6555, x: 11237)> Size: 295MB
# dask.array<open_rasterio-ca8b0d41e36d325c48752dd1eb212ef3<this-array>, shape=(1, 6555, 11237), dtype=float32, chunksize=(1, 2986, 11237), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) int64 8B 1
#   * y            (y) float64 52kB -0.083 -0.08309 -0.08318 ... -0.6662 -0.6663
#   * x            (x) float64 90kB 121.5 121.5 121.5 121.5 ... 122.5 122.5 122.5
#     spatial_ref  int64 8B 0
# Attributes:
#     AREA_OR_POINT:  Point
#     scale_factor:   1.0
#     add_offset:     0.0
#     units:          metre

# %%
pygmt.grd2xyz(
    grid=new_dem,
    output_type='file',
    outfile=new_path.with_suffix('.xyz'),
)
# Out:
# c:\Users\LENOVO\miniforge3\envs\py3_12\Lib\site-packages\pygmt\helpers\decorators.py:818: RuntimeWarning: Input image has dtype: float32 which is unsupported, and may result in an incorrect output. Please recast image to a uint8 dtype and/or scale to 0-255 range, e.g. using a histogram equalization function like skimage.exposure.equalize_hist.
#   return module_func(*args, **kwargs)

# %%
dem2xyz(old_path, crs='EPSG:4326', chunks='auto', default_name='elevation')

# %%
dem2xyz(new_path, chunks='auto', default_name='elevation')
